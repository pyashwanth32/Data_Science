# %%
import numpy as np
import wave
import matplotlib.pyplot as plt
import glob

# %%
def read_wav_as_np_array(file_path):
    with wave.open(file_path, 'r') as wav_file:
        # Extract RAW audio from WAV file
        raw_audio = wav_file.readframes(wav_file.getnframes())
        
        # Convert RAW audio to NumPy array based on the number of channels
        audio_array = np.frombuffer(raw_audio, dtype=np.int16)
        
        # If the audio file is stereo, reshape the array accordingly
        if wav_file.getnchannels() == 2:
            audio_array = audio_array.reshape((-1, 2))

        return audio_array.astype('float32')

# %%
pwd
# Out:
# 'D:\\Yashwanth\\HTW_Berlin\\Semester_1\\Data_Science\\Lecture7'

# %%
#yes1=read_wav_as_np_array('yes/yes1.wav')
yes1=read_wav_as_np_array('yes1.wav')

# %%
yessss=read_wav_as_np_array('yes/yes.wav')

# %%
plt.plot(yessss)

# %%
yes1.shape
# Out:
# (16491, 2)

# %%
plt.plot(yes1)

# %%
#yes2=read_wav_as_np_array('yes/yes2.wav')
yes2=read_wav_as_np_array('yes2.wav')

# %%
yes1.shape,yes2.shape
# Out:
# ((16491, 2), (19858, 2))

# %%
no1=read_wav_as_np_array('no1.wav')

# %%
plt.plot(no1)

# %%
for fn in glob.glob("yes/*.wav"):
    a=read_wav_as_np_array(fn)
    print(len(a))

# %%
for fn in glob.glob("no/*.wav"):
    a=read_wav_as_np_array(fn)
    print(len(a))

# %%
data_multiplication=5-
x=[]
y=[]
for fn in glob.glob(yes/*.wav
