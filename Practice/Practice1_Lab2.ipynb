# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=[4,7,2,5]
x
# Out:
# [4, 7, 2, 5]

# %%
y=[3,10,4,6]

# %%
plt.plot(x,y,'.')

# %%
a,b=7,2

# %%
yh=[a*h+b for h in x]
yh
# Out:
# [30, 51, 16, 37]

# %%
[h for h in x]
# Out:
# [4, 7, 2, 5]

# %%
[yh[i]-y[i] for i in range(len(y))]
# Out:
# [27, 41, 12, 31]

# %%
values=[(a/2-5,b/2-5) for a in range(20) for b in range(20)]
values
# Out:
# [(-5.0, -5.0),
#  (-5.0, -4.5),
#  (-5.0, -4.0),
#  (-5.0, -3.5),
#  (-5.0, -3.0),
#  (-5.0, -2.5),
#  (-5.0, -2.0),
#  (-5.0, -1.5),
#  (-5.0, -1.0),
#  (-5.0, -0.5),
#  (-5.0, 0.0),
#  (-5.0, 0.5),
#  (-5.0, 1.0),
#  (-5.0, 1.5),
#  (-5.0, 2.0),
#  (-5.0, 2.5),
#  (-5.0, 3.0),
#  (-5.0, 3.5),
#  (-5.0, 4.0),
#  (-5.0, 4.5),
#  (-4.5, -5.0),
#  (-4.5, -4.5),
#  (-4.5, -4.0),
#  (-4.5, -3.5),
#  (-4.5, -3.0),
#  (-4.5, -2.5),
#  (-4.5, -2.0),
#  (-4.5, -1.5),
#  (-4.5, -1.0),
#  (-4.5, -0.5),
#  (-4.5, 0.0),
#  (-4.5, 0.5),
#  (-4.5, 1.0),
#  (-4.5, 1.5),
#  (-4.5, 2.0),
#  (-4.5, 2.5),
#  (-4.5, 3.0),
#  (-4.5, 3.5),
#  (-4.5, 4.0),
#  (-4.5, 4.5),
#  (-4.0, -5.0),
#  (-4.0, -4.5),
#  (-4.0, -4.0),
#  (-4.0, -3.5),
#  (-4.0, -3.0),
#  (-4.0, -2.5),
#  (-4.0, -2.0),
#  (-4.0, -1.5),
#  (-4.0, -1.0),
#  (-4.0, -0.5),
#  (-4.0, 0.0),
#  (-4.0, 0.5),
#  (-4.0, 1.0),
#  (-4.0, 1.5),
#  (-4.0, 2.0),
#  (-4.0, 2.5),
#  (-4.0, 3.0),
#  (-4.0, 3.5),
#  (-4.0, 4.0),
#  (-4.0, 4.5),
# ...

# %%
x
# Out:
# [4, 7, 2, 5]

# %%
y
# Out:
# [3, 10, 4, 6]

# %%
[(u-v)**2 for u in x for v in y]
# Out:
# [1, 36, 0, 4, 16, 9, 9, 1, 1, 64, 4, 16, 4, 25, 1, 1]

# %%
[(u-v)**2 for u,v in zip(x,y)]
# Out:
# [1, 9, 4, 1]

# %%
x
# Out:
# [4, 7, 2, 5]

# %%
y
# Out:
# [3, 10, 4, 6]

# %%
def sse(x,y):
    return sum((u-v)**2 for u,v in zip(x,y))

# %%
sse(x,y)
# Out:
# 15

# %%
def predict(m,x):
    u,v=m
    return [u*x+v for x in x]

# %%
predict((2,3),x)
# Out:
# [11, 17, 7, 13]

# %%
y
# Out:
# [3, 10, 4, 6]

# %%
x
# Out:
# [4, 7, 2, 5]

# %%
values
# Out:
# [(-5.0, -5.0),
#  (-5.0, -4.5),
#  (-5.0, -4.0),
#  (-5.0, -3.5),
#  (-5.0, -3.0),
#  (-5.0, -2.5),
#  (-5.0, -2.0),
#  (-5.0, -1.5),
#  (-5.0, -1.0),
#  (-5.0, -0.5),
#  (-5.0, 0.0),
#  (-5.0, 0.5),
#  (-5.0, 1.0),
#  (-5.0, 1.5),
#  (-5.0, 2.0),
#  (-5.0, 2.5),
#  (-5.0, 3.0),
#  (-5.0, 3.5),
#  (-5.0, 4.0),
#  (-5.0, 4.5),
#  (-4.5, -5.0),
#  (-4.5, -4.5),
#  (-4.5, -4.0),
#  (-4.5, -3.5),
#  (-4.5, -3.0),
#  (-4.5, -2.5),
#  (-4.5, -2.0),
#  (-4.5, -1.5),
#  (-4.5, -1.0),
#  (-4.5, -0.5),
#  (-4.5, 0.0),
#  (-4.5, 0.5),
#  (-4.5, 1.0),
#  (-4.5, 1.5),
#  (-4.5, 2.0),
#  (-4.5, 2.5),
#  (-4.5, 3.0),
#  (-4.5, 3.5),
#  (-4.5, 4.0),
#  (-4.5, 4.5),
#  (-4.0, -5.0),
#  (-4.0, -4.5),
#  (-4.0, -4.0),
#  (-4.0, -3.5),
#  (-4.0, -3.0),
#  (-4.0, -2.5),
#  (-4.0, -2.0),
#  (-4.0, -1.5),
#  (-4.0, -1.0),
#  (-4.0, -0.5),
#  (-4.0, 0.0),
#  (-4.0, 0.5),
#  (-4.0, 1.0),
#  (-4.0, 1.5),
#  (-4.0, 2.0),
#  (-4.0, 2.5),
#  (-4.0, 3.0),
#  (-4.0, 3.5),
#  (-4.0, 4.0),
#  (-4.0, 4.5),
# ...

# %%
y
# Out:
# [3, 10, 4, 6]

# %%
plt.plot(values)

# %%
y
# Out:
# [3, 10, 4, 6]

# %%
[sse(y,predict(m,x)) for m in values]
# Out:
# [4941.0,
#  4809.0,
#  4679.0,
#  4551.0,
#  4425.0,
#  4301.0,
#  4179.0,
#  4059.0,
#  3941.0,
#  3825.0,
#  3711.0,
#  3599.0,
#  3489.0,
#  3381.0,
#  3275.0,
#  3171.0,
#  3069.0,
#  2969.0,
#  2871.0,
#  2775.0,
#  4284.5,
#  4161.5,
#  4040.5,
#  3921.5,
#  3804.5,
#  3689.5,
#  3576.5,
#  3465.5,
#  3356.5,
#  3249.5,
#  3144.5,
#  3041.5,
#  2940.5,
#  2841.5,
#  2744.5,
#  2649.5,
#  2556.5,
#  2465.5,
#  2376.5,
#  2289.5,
#  3675.0,
#  3561.0,
#  3449.0,
#  3339.0,
#  3231.0,
#  3125.0,
#  3021.0,
#  2919.0,
#  2819.0,
#  2721.0,
#  2625.0,
#  2531.0,
#  2439.0,
#  2349.0,
#  2261.0,
#  2175.0,
#  2091.0,
#  2009.0,
#  1929.0,
#  1851.0,
#  3112.5,
#  3007.5,
#  2904.5,
#  2803.5,
#  2704.5,
#  2607.5,
#  2512.5,
#  2419.5,
#  2328.5,
#  2239.5,
#  2152.5,
#  2067.5,
#  1984.5,
#  1903.5,
#  1824.5,
#  1747.5,
#  1672.5,
#  1599.5,
#  1528.5,
#  1459.5,
#  2597.0,
#  2501.0,
#  2407.0,
#  2315.0,
#  2225.0,
#  2137.0,
#  2051.0,
#  1967.0,
#  1885.0,
#  1805.0,
# ...

# %%
y
# Out:
# [3, 10, 4, 6]

# %%
values
# Out:
# [(-5.0, -5.0),
#  (-5.0, -4.5),
#  (-5.0, -4.0),
#  (-5.0, -3.5),
#  (-5.0, -3.0),
#  (-5.0, -2.5),
#  (-5.0, -2.0),
#  (-5.0, -1.5),
#  (-5.0, -1.0),
#  (-5.0, -0.5),
#  (-5.0, 0.0),
#  (-5.0, 0.5),
#  (-5.0, 1.0),
#  (-5.0, 1.5),
#  (-5.0, 2.0),
#  (-5.0, 2.5),
#  (-5.0, 3.0),
#  (-5.0, 3.5),
#  (-5.0, 4.0),
#  (-5.0, 4.5),
#  (-4.5, -5.0),
#  (-4.5, -4.5),
#  (-4.5, -4.0),
#  (-4.5, -3.5),
#  (-4.5, -3.0),
#  (-4.5, -2.5),
#  (-4.5, -2.0),
#  (-4.5, -1.5),
#  (-4.5, -1.0),
#  (-4.5, -0.5),
#  (-4.5, 0.0),
#  (-4.5, 0.5),
#  (-4.5, 1.0),
#  (-4.5, 1.5),
#  (-4.5, 2.0),
#  (-4.5, 2.5),
#  (-4.5, 3.0),
#  (-4.5, 3.5),
#  (-4.5, 4.0),
#  (-4.5, 4.5),
#  (-4.0, -5.0),
#  (-4.0, -4.5),
#  (-4.0, -4.0),
#  (-4.0, -3.5),
#  (-4.0, -3.0),
#  (-4.0, -2.5),
#  (-4.0, -2.0),
#  (-4.0, -1.5),
#  (-4.0, -1.0),
#  (-4.0, -0.5),
#  (-4.0, 0.0),
#  (-4.0, 0.5),
#  (-4.0, 1.0),
#  (-4.0, 1.5),
#  (-4.0, 2.0),
#  (-4.0, 2.5),
#  (-4.0, 3.0),
#  (-4.0, 3.5),
#  (-4.0, 4.0),
#  (-4.0, 4.5),
# ...

# %%
result=[sse(y,predict(m,x)) for m in values]
result
# Out:
# [4941.0,
#  4809.0,
#  4679.0,
#  4551.0,
#  4425.0,
#  4301.0,
#  4179.0,
#  4059.0,
#  3941.0,
#  3825.0,
#  3711.0,
#  3599.0,
#  3489.0,
#  3381.0,
#  3275.0,
#  3171.0,
#  3069.0,
#  2969.0,
#  2871.0,
#  2775.0,
#  4284.5,
#  4161.5,
#  4040.5,
#  3921.5,
#  3804.5,
#  3689.5,
#  3576.5,
#  3465.5,
#  3356.5,
#  3249.5,
#  3144.5,
#  3041.5,
#  2940.5,
#  2841.5,
#  2744.5,
#  2649.5,
#  2556.5,
#  2465.5,
#  2376.5,
#  2289.5,
#  3675.0,
#  3561.0,
#  3449.0,
#  3339.0,
#  3231.0,
#  3125.0,
#  3021.0,
#  2919.0,
#  2819.0,
#  2721.0,
#  2625.0,
#  2531.0,
#  2439.0,
#  2349.0,
#  2261.0,
#  2175.0,
#  2091.0,
#  2009.0,
#  1929.0,
#  1851.0,
#  3112.5,
#  3007.5,
#  2904.5,
#  2803.5,
#  2704.5,
#  2607.5,
#  2512.5,
#  2419.5,
#  2328.5,
#  2239.5,
#  2152.5,
#  2067.5,
#  1984.5,
#  1903.5,
#  1824.5,
#  1747.5,
#  1672.5,
#  1599.5,
#  1528.5,
#  1459.5,
#  2597.0,
#  2501.0,
#  2407.0,
#  2315.0,
#  2225.0,
#  2137.0,
#  2051.0,
#  1967.0,
#  1885.0,
#  1805.0,
# ...

# %%
minimum=min(result)
minimum
# Out:
# 8.5

# %%
plt.plot(result)

# %%
d=(minimum==r for r in result)
d
# Out:
# <generator object <genexpr> at 0x000001659A5C6B50>

# %%
sum(minimum==r for r in result)
# Out:
# 1

# %%
bestmodel=[r for r in values if sse(y,predict(r,x))==minimum]
bestmodel
# Out:
# [(1.5, -1.0)]

# %%
plt.plot(x,y,'.')
#plt.plot(x,predict(bestmodel,x),'*')
plt.plot(x,predict(bestmodel[0],x),"o",ms=20)
plt.grid(1)

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.85347999],
#        [0.85347999, 1.        ]])

# %%
np.corrcoef(x,y)[0,1]
# Out:
# 0.8534799901845883

# %%
np.corrcoef(y,(predict(bestmodel[0],x)))
# Out:
# array([[1.        , 0.85347999],
#        [0.85347999, 1.        ]])

# %%
#why are the above 2 values same??
